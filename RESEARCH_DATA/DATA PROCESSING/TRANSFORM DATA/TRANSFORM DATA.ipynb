# %% [markdown]
# # CPI VIETNAM

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "cpi_vietnam.xlsx"  # Đảm bảo file này có sẵn trong thư mục chạy
cpi_df = pd.read_excel(file_path, index_col=0)

# Tạo danh sách ngày từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')

# Chuyển đổi dữ liệu CPI từ bảng tháng sang dạng dài
cpi_long = cpi_df.reset_index().melt(id_vars=["Tháng trước = 100"], var_name="Year", value_name="CPI")

# Định nghĩa ánh xạ tên tháng thành số
month_mapping = {"Tháng 1": 1, "Tháng 2": 2, "Tháng 3": 3, "Tháng 4": 4, "Tháng 5": 5, "Tháng 6": 6,
                 "Tháng 7": 7, "Tháng 8": 8, "Tháng 9": 9, "Tháng 10": 10, "Tháng 11": 11, "Tháng 12": 12}
cpi_long["Month"] = cpi_long["Tháng trước = 100"].map(month_mapping)

# Chuyển đổi thành ngày đầu tháng
cpi_long["Date"] = pd.to_datetime(cpi_long[["Year", "Month"]].assign(day=1))

# Tạo DataFrame chứa danh sách ngày
date_df = pd.DataFrame({"Date": date_range})

# Gộp dữ liệu để gán CPI cho từng ngày
merged_df = date_df.merge(cpi_long[["Date", "CPI"]], on="Date", how="left")

# Điền CPI cho tất cả các ngày trong tháng bằng forward fill
merged_df["CPI"] = merged_df["CPI"].fillna(method="ffill")

# Xuất file Excel
output_file = "CPI_Daily_Vietnam.xlsx"
merged_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18776\793935921.py:28: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   merged_df["CPI"] = merged_df["CPI"].fillna(method="ffill")
# File CPI_Daily_Vietnam.xlsx đã được tạo thành công!

# %% [markdown]
# # VÀNG THẾ GIỚI

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "world_gold_price.xlsx"  # Đảm bảo file này có sẵn trong thư mục chạy
gold_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang định dạng datetime
gold_df["Time"] = pd.to_datetime(gold_df["Time"], format="%d/%m/%Y")

# Tạo danh sách ngày liên tục từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Time": date_range})

# Gộp dữ liệu để có danh sách ngày liên tục
gold_full_df = date_df.merge(gold_df, on="Time", how="left")

# Xuất file Excel
output_file = "new.xlsx"
gold_full_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %% [markdown]
# # GIÁ DẦU

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "oil_price.xlsx"
gold_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang định dạng datetime
gold_df["Time"] = pd.to_datetime(gold_df["Time"], format="%d/%m/%Y")

# Tạo danh sách ngày liên tục từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Time": date_range})

# Gộp dữ liệu để có danh sách ngày liên tục
gold_full_df = date_df.merge(gold_df, on="Time", how="left")

# Xuất file Excel
output_file = "new.xlsx"
gold_full_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %% [markdown]
# # Tỷ giá VNU/USD

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "USD-VND.xlsx"
gold_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang định dạng datetime
gold_df["Time"] = pd.to_datetime(gold_df["Time"], format="%d/%m/%Y")

# Tạo danh sách ngày liên tục từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Time": date_range})

# Gộp dữ liệu để có danh sách ngày liên tục
gold_full_df = date_df.merge(gold_df, on="Time", how="left")

# Xuất file Excel
output_file = "new.xlsx"
gold_full_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %% [markdown]
# # VN_Index

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "VN-index.xlsx"
gold_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang định dạng datetime
gold_df["Time"] = pd.to_datetime(gold_df["Time"], format="%m/%d/%Y")

# Tạo danh sách ngày liên tục từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Time": date_range})

# Gộp dữ liệu để có danh sách ngày liên tục
gold_full_df = date_df.merge(gold_df, on="Time", how="left")

# Xuất file Excel
output_file = "new.xlsx"
gold_full_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %% [markdown]
# # CPI_USA

# %%
import pandas as pd
# Đọc dữ liệu từ file Excel
file_path = "CPI _USA.xlsx"
cpi_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang datetime
def parse_time(value):
    return pd.to_datetime(value, format="%m/%Y")

cpi_df["Time"] = cpi_df["Time"].apply(parse_time)

# Tạo danh sách ngày từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Date": date_range})

# Thêm cột Year-Month để khớp với dữ liệu CPI
date_df["YearMonth"] = date_df["Date"].dt.to_period("M")
cpi_df["YearMonth"] = cpi_df["Time"].dt.to_period("M")

# Gộp dữ liệu CPI theo tháng vào danh sách ngày
daily_cpi_df = date_df.merge(cpi_df[["YearMonth", "Value"]], on="YearMonth", how="left")

# Loại bỏ cột YearMonth không cần thiết
daily_cpi_df.drop(columns=["YearMonth"], inplace=True)

# Xuất file Excel
output_file = "new.xlsx"
daily_cpi_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %% [markdown]
# # CUNG TIỀN M2

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "M2.xlsx" 
m2_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang datetime
def parse_time(value):
    return pd.to_datetime(value, format="Tháng %m/%Y")

m2_df["Time"] = m2_df["Time"].apply(parse_time)

# Tạo danh sách ngày từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Date": date_range})

# Thêm cột Year-Month để khớp với dữ liệu M2
date_df["YearMonth"] = date_df["Date"].dt.to_period("M")
m2_df["YearMonth"] = m2_df["Time"].dt.to_period("M")

# Gộp dữ liệu M2 theo tháng vào danh sách ngày
daily_m2_df = date_df.merge(m2_df[["YearMonth", "SM_M2"]], on="YearMonth", how="left")

# Loại bỏ cột YearMonth không cần thiết
daily_m2_df.drop(columns=["YearMonth"], inplace=True)

# Xuất file Excel
output_file = "new.xlsx"
daily_m2_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "SX_CN.xlsx" 
m2_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang datetime
def parse_time(value):
    return pd.to_datetime(value, format="Tháng %m/%Y")

m2_df["Time"] = m2_df["Time"].apply(parse_time)

# Tạo danh sách ngày từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Date": date_range})

# Thêm cột Year-Month để khớp với dữ liệu M2
date_df["YearMonth"] = date_df["Date"].dt.to_period("M")
m2_df["YearMonth"] = m2_df["Time"].dt.to_period("M")

# Gộp dữ liệu M2 theo tháng vào danh sách ngày
daily_m2_df = date_df.merge(m2_df[["YearMonth", "Value"]], on="YearMonth", how="left")

# Loại bỏ cột YearMonth không cần thiết
daily_m2_df.drop(columns=["YearMonth"], inplace=True)

# Xuất file Excel
output_file = "new.xlsx"
daily_m2_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %% [markdown]
# # Lãi gửi ngân hàng

# %%
import pandas as pd

# Đọc dữ liệu từ file Excel
file_path = "INTEREST_RATE.xlsx"
gold_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang định dạng datetime
gold_df["Time"] = pd.to_datetime(gold_df["Time"], format="%d/%m/%Y")

# Tạo danh sách ngày liên tục từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Time": date_range})

# Gộp dữ liệu để có danh sách ngày liên tục
gold_full_df = date_df.merge(gold_df, on="Time", how="left")

# Xuất file Excel
output_file = "new.xlsx"
gold_full_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!

# %% [markdown]
# # GSI

# %%
import pandas as pd
# Đọc dữ liệu từ file Excel
file_path = "GSI_VN.xlsx"
cpi_df = pd.read_excel(file_path)

# Chuyển đổi cột "Time" sang datetime
def parse_time(value):
    return pd.to_datetime(value, format="%Y-%m-%d")

cpi_df["Time"] = cpi_df["Time"].apply(parse_time)

# Tạo danh sách ngày từ 1/1/2010 đến 31/12/2024
date_range = pd.date_range(start="2010-01-01", end="2024-12-31", freq='D')
date_df = pd.DataFrame({"Date": date_range})

# Thêm cột Year-Month để khớp với dữ liệu CPI
date_df["YearMonth"] = date_df["Date"].dt.to_period("M")
cpi_df["YearMonth"] = cpi_df["Time"].dt.to_period("M")

# Gộp dữ liệu CPI theo tháng vào danh sách ngày
daily_cpi_df = date_df.merge(cpi_df[["YearMonth", "Value"]], on="YearMonth", how="left")

# Loại bỏ cột YearMonth không cần thiết
daily_cpi_df.drop(columns=["YearMonth"], inplace=True)

# Xuất file Excel
output_file = "new.xlsx"
daily_cpi_df.to_excel(output_file, index=False)

print(f"File {output_file} đã được tạo thành công!")
# Out:
# File new.xlsx đã được tạo thành công!
